# %% [markdown]
# # YOLO11n Baseline
#
# This notebook is reserved for exploratory baseline experiments. Keep reusable training, evaluation, and inference logic in `src/` so experiments remain reproducible.

# %%
from pathlib import Path
import yaml

config_path = Path('../configs/models/yolo11n.yaml')
with config_path.open('r', encoding='utf-8') as file:
    config = yaml.safe_load(file)

config

# %% [markdown]
# Training should normally be run from the repository root:
#
# ```bash
# python -m src.training.train_yolo --config configs/models/yolo11n.yaml
# ```
